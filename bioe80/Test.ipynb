# %% [raw]
# def say_hello(recipient):
#     return 'Hello, {}!'.format(recipient)
#
# say_hello('Tim')

# %%
1+1
# Out:
# 2

# %%
2+2
# Out:
# 4

# %%
print("This is a test")
# Out:
# This is a test
